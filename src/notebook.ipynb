# %%
import logging

def get_logger(    
        LOG_FORMAT     = '%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
        LOG_NAME       = '',
        LOG_FILE_INFO  = 'file.log',
        LOG_FILE_ERROR = 'file.err'):

    log           = logging.getLogger(LOG_NAME)
    log_formatter = logging.Formatter(LOG_FORMAT)

    # comment this to suppress console output
    stream_handler = logging.StreamHandler()
    stream_handler.setFormatter(log_formatter)
    log.addHandler(stream_handler)

    file_handler_info = logging.FileHandler(LOG_FILE_INFO, mode='w')
    file_handler_info.setFormatter(log_formatter)
    file_handler_info.setLevel(logging.INFO)
    log.addHandler(file_handler_info)

    file_handler_error = logging.FileHandler(LOG_FILE_ERROR, mode='w')
    file_handler_error.setFormatter(log_formatter)
    file_handler_error.setLevel(logging.ERROR)
    log.addHandler(file_handler_error)

    log.setLevel(logging.INFO)

    return log

my_logger = get_logger()

# %%
# !pip install torch
from graph_init import initialize_graph
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3

db = sqlite3.connect(":memory:", check_same_thread=False)
memory = SqliteSaver(db)
# Initialize the graph
engine = initialize_graph()

# # Compile the graph
runnable = engine.compile(checkpointer=memory)

# Compile the graph with interrupt
# runnable = engine.compile(checkpointer=memory,  interrupt_before=["IoT_engine","generator_agent", "scrapper", "GoogleMaps"])
# Out:
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Requesting OCSP data
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    Starting new HTTP connection (1): r10.o.lencr.org:80
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Requesting OCSP data
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    Requesting OCSP data
# DEBUG    http://r10.o.lencr.org:80 "POST / HTTP/1.1" 200 504
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# DEBUG    Starting new HTTP connection (1): r10.o.lencr.org:80
# DEBUG    Verifying response
# DEBUG    Starting new HTTP connection (1): r10.o.lencr.org:80
# DEBUG    Responder is issuer
# DEBUG    Caching OCSP response.
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>
# DEBUG    http://r10.o.lencr.org:80 "POST / HTTP/1.1" 200 504
# DEBUG    OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# DEBUG    Verifying response
# DEBUG    http://r10.o.lencr.org:80 "POST / HTTP/1.1" 200 504
# DEBUG    Responder is issuer
# DEBUG    OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# DEBUG    Verifying response
# DEBUG    Responder is issuer
# DEBUG    Caching OCSP response.
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>
# DEBUG    Caching OCSP response.
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Requesting OCSP data
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Using cached OCSP response.
# DEBUG    Requesting OCSP data
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    Using cached OCSP response.
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>
# DEBUG    Peer did not staple an OCSP response
# DEBUG    Requesting OCSP data
# DEBUG    Trying http://r10.o.lencr.org
# DEBUG    Using cached OCSP response.
# DEBUG    OCSP cert status: <OCSPCertStatus.GOOD: 0>

# %%
from IPython.display import Image, display

display(Image(runnable.get_graph().draw_mermaid_png()))
# Out:
# DEBUG    Starting new HTTPS connection (1): mermaid.ink:443
# DEBUG    https://mermaid.ink:443 "GET ...?bgColor=!white HTTP/1.1" 200 50688

# %%
# You can add code here to execute the graph or further actions.
thread = {"configurable": {"thread_id": "1"}}


human_message = HumanMessage(content="I want to drink coffee in Oshawa tomorow")
messages = [human_message]

result = runnable.invoke({"messages":messages}, thread)

print(result)
# Out:
# DEBUG    Starting new HTTPS connection (1): api.smith.langchain.com:443
# INFO     entering assistant node
# DEBUG    Request options: {'method': 'post', 'url': '/openai/v1/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\nAct as an assistant  and answer user queries ONLY if you can \nUser queries may fall into one of the following categories:\n1- Greeting/General: Greeting you or answering a general question that you can ONLY answer, or thank you at the end of the conversations.\n2- Service Recommendation: Asking for a recommendation for a service or a place to visit, such as I want to drink coffee, I am looking for a Middle Eastern restaurant, or Do you know any close hospital?\n3- Hard Question: General questions you can\'t answer, such as: who is the current president of the United States of America? Or any question related to current events happening as you don\'t have access to the current event happening right now. the user may ask you to look for it\nYour response must follow the following JSON  objects based on each category:\n 1- Greeting/General: you need to provide your response ONLY in a JSON object as shown:\n{\n  "query-type": "greeting-general", // String: Type of the query (e.g., Hello, what\'s the internet?)\n  "response": "write your response here" // String: The response from the LLM\n}\n2-Service Recommendation: try to extract the service type and the city, country, Address, or Coordinates if mentioned. Your response is ONLY a JSON object. This JSON object must follow the following structure and set "" (empty string) for the value of the keys that you can\'t extract.\n{\n  "query-type": "service-recommendation", // String: Type of the query (e.g., coffee shop)\n  "service": "extracted service type", // String: The type of service extracted from the user\'s input\n  "city": "extracted city", // String: The city name extracted from the user\'s input\n  "country": "extracted country", // String: The country name extracted from the user\'s input \n  "address": "extracted address", // String: The full address extracted from the user\'s input\n  "coordinates": [extracted_latitude, extracted_longitude], // Array of Numbers: The latitude and longitude coordinates (e.g., [12.34, 56.78]) and set [0, 0] if not extracted.\n  "question": "extracted question based on the context of the user conversation" // String: The user\'s question or request extracted based on context\n}\n3- Hard Question/current events: extract the question from the user context and provide your response ONLY JSON object as shown:\n{\n  "query-type": "hard-question", // String: Type of the query (e.g., what\'s happening now in Egypt? )\n  "question": "extracted question based on the context of the user conversation" // String: The specific hard question extracted from the user\'s conversation context\n}\n\nRespond ONLY with one of the JSON objects defined above without writing the provided comments on each key-value.\n'}, {'role': 'user', 'content': 'I want to drink coffee in Oshawa tomorow'}], 'model': 'llama3-8b-8192', 'n': 1, 'stop': None, 'stream': False, 'temperature': 1e-08}}
# DEBUG    Sending HTTP Request: POST https://api.groq.com/openai/v1/chat/completions
# DEBUG    connect_tcp.started host='api.groq.com' port=443 local_address=None timeout=None socket_options=None
# DEBUG    connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000011485F7EBD0>
# DEBUG    start_tls.started ssl_context=<ssl.SSLContext object at 0x00000114F5D72960> server_hostname='api.groq.com' timeout=None
# DEBUG    start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000011485F7E990>
# DEBUG    send_request_headers.started request=<Request [b'POST']>
# DEBUG    send_request_headers.complete
# DEBUG    send_request_body.started request=<Request [b'POST']>
# DEBUG    send_request_body.complete
# DEBUG    receive_response_headers.started request=<Request [b'POST']>
# DEBUG    receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Aug 2024 04:05:26 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Cache-Control', b'private, max-age=0, no-store, no-cache, must-revalidate'), (b'vary', b'Origin'), (b'x-ratelimit-limit-requests', b'14400'), (b'x-ratelimit-limit-tokens', b'30000'), (b'x-ratelimit-remaining-requests', b'14399'), (b'x-ratelimit-remaining-tokens', b'29308'), (b'x-ratelimit-reset-requests', b'6s'), (b'x-ratelimit-reset-tokens', b'1.384s'), (b'x-request-id', b'req_01j5f85x8xeyqsp1nfcb84a8jy'), (b'via', b'1.1 google'), (b'alt-svc', b'h3=":443"; ma=86400'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=L.hSfsgmXWkV8_WioI8Cz.3IctANkVHeqeSief7e93s-1723867526-1.0.1.1-Uc_A_.4Sju8YfbIlm3gPafxwr6.zSpDiR22H7_dmICvqQv0xfkTIehmEdBh_Fxk0DpkkKXaCgLpm_3Eo0oLjew; path=/; expires=Sat, 17-Aug-24 04:35:26 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8b46c927ef94ac2d-YYZ'), (b'Content-Encoding', b'br')])
# INFO     HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG    receive_response_body.started request=<Request [b'POST']>
# DEBUG    receive_response_body.complete
# DEBUG    response_closed.started
# DEBUG    response_closed.complete
# DEBUG    HTTP Response: POST https://api.groq.com/openai/v1/chat/completions "200 OK" Headers({'date': 'Sat, 17 Aug 2024 04:05:26 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'private, max-age=0, no-store, no-cache, must-revalidate', 'vary': 'Origin', 'x-ratelimit-limit-requests': '14400', 'x-ratelimit-limit-tokens': '30000', 'x-ratelimit-remaining-requests': '14399', 'x-ratelimit-remaining-tokens': '29308', 'x-ratelimit-reset-requests': '6s', 'x-ratelimit-reset-tokens': '1.384s', 'x-request-id': 'req_01j5f85x8xeyqsp1nfcb84a8jy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=86400', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=L.hSfsgmXWkV8_WioI8Cz.3IctANkVHeqeSief7e93s-1723867526-1.0.1.1-Uc_A_.4Sju8YfbIlm3gPafxwr6.zSpDiR22H7_dmICvqQv0xfkTIehmEdBh_Fxk0DpkkKXaCgLpm_3Eo0oLjew; path=/; expires=Sat, 17-Aug-24 04:35:26 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None', 'server': 'cloudflare', 'cf-ray': '8b46c927ef94ac2d-YYZ', 'content-encoding': 'br'})
# INFO     content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}' response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.169661869, 'queue_time': 0.0017162900000000092, 'total_time': 0.232161869}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None} id='run-7c86cbe7-cf72-4934-8b1b-4c5be8c1290e-0' usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707}
# DEBUG    Nominatim.geocode: https://nominatim.openstreetmap.org/search?q=Oshawa&format=json&limit=1
# DEBUG    Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# DEBUG    https://api.smith.langchain.com:443 "GET /info HTTP/1.1" 200 455
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /search?q=Oshawa&format=json&limit=1 HTTP/1.1" 200 453
# DEBUG    Nominatim.reverse: https://nominatim.openstreetmap.org/reverse?lat=43.8975558&lon=-78.8635324&format=json&addressdetails=1
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /reverse?lat=43.8975558&lon=-78.8635324&format=json&addressdetails=1 HTTP/1.1" 200 787
# DEBUG    Nominatim.geocode: https://nominatim.openstreetmap.org/search?q=Oshawa&format=json&limit=1
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /search?q=Oshawa&format=json&limit=1 HTTP/1.1" 200 453
# INFO     {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}
# INFO     GoogleMaps
# INFO     {'node': ['assistant_agent'], 'location_finder_results': {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}, 'call': 'GoogleMaps', 'query': 'I want to drink coffee in Oshawa tomorrow', 'messages': [AIMessage(content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}', response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.169661869, 'queue_time': 0.0017162900000000092, 'total_time': 0.232161869}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-7c86cbe7-cf72-4934-8b1b-4c5be8c1290e-0', usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707})]}
# INFO     Using GoogleMaps
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/place/textsearch/json?query=I+want+to+drink+coffee+in+Oshawa+tomorrow&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 42167
# DEBUG    Starting new HTTP connection (1): router.project-osrm.org:80
# DEBUG    http://router.project-osrm.org:80 "GET /table/v1/driving/-78.8635324,43.8975558;-78.8652079,43.8998634;-78.86398609999999,43.8978262;-78.8625184,43.8990501?annotations=duration HTTP/1.1" 200 562
# DEBUG    Request options: {'method': 'post', 'url': '/openai/v1/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "\nAct as an assistant, generate a like-human response and recommend only one or Two services, giving the suggested service details in this list of JSON objects.\n    List of JSON objects.: [{'entity_name': 'Aves Coffee Co.', 'address': '9 William St W, Oshawa, ON L1G 4B7, Canada', 'rate': 4.9, 'estimated_travel_time': '1.43 mins'}, {'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '0.94 mins'}, {'entity_name': 'BOND|ST Cafe', 'address': '44 Bond St E First Floor, Oshawa, ON L1G 1B1, Canada', 'rate': 4.9, 'estimated_travel_time': '0.95 mins'}]\n    \n- Do not include any explanations.\n- Generate like-human response. \n- Do not use the JSON format in your response. \n- Do not make assumptions. \n- Recommend only the service based on the following parameters:\n\t\tb) Travel time\n\t\td) Rate\n  Note: these parameters may not mentioned explicitly in the query. For examples, (Travel time, closer, nearest) (Occupancy, not crowded) (good review, Rate) all have the same meaning, and   So, try to extract these parameters based understanding the user query. \n- If the user does not specify any preferences, recommend based on your reasoning and differentiating between these available parameters without saying (you didn't specify any pereferences).\n- You can't book a service.\n- You need to clarify that you can't suggest based on estimated service time as you don't have access to real-time sensing data\n- At the end of your response, in a new line, mention the data source on GoogleMaps agent.\n"}, {'role': 'user', 'content': 'I want to drink coffee in Oshawa tomorow'}], 'model': 'llama3-8b-8192', 'n': 1, 'stop': None, 'stream': False, 'temperature': 1e-08}}
# DEBUG    Sending HTTP Request: POST https://api.groq.com/openai/v1/chat/completions
# DEBUG    send_request_headers.started request=<Request [b'POST']>
# DEBUG    send_request_headers.complete
# DEBUG    send_request_body.started request=<Request [b'POST']>
# DEBUG    send_request_body.complete
# DEBUG    receive_response_headers.started request=<Request [b'POST']>
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33
# DEBUG    receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Aug 2024 04:05:30 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Cache-Control', b'private, max-age=0, no-store, no-cache, must-revalidate'), (b'vary', b'Origin'), (b'x-ratelimit-limit-requests', b'14400'), (b'x-ratelimit-limit-tokens', b'30000'), (b'x-ratelimit-remaining-requests', b'14398'), (b'x-ratelimit-remaining-tokens', b'29589'), (b'x-ratelimit-reset-requests', b'7.903999999s'), (b'x-ratelimit-reset-tokens', b'822ms'), (b'x-request-id', b'req_01j5f86190fbdtbqayw9jgkm3p'), (b'via', b'1.1 google'), (b'alt-svc', b'h3=":443"; ma=86400'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8b46c9418895ac2d-YYZ'), (b'Content-Encoding', b'br')])
# INFO     HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG    receive_response_body.started request=<Request [b'POST']>
# DEBUG    receive_response_body.complete
# DEBUG    response_closed.started
# DEBUG    response_closed.complete
# DEBUG    HTTP Response: POST https://api.groq.com/openai/v1/chat/completions "200 OK" Headers({'date': 'Sat, 17 Aug 2024 04:05:30 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'private, max-age=0, no-store, no-cache, must-revalidate', 'vary': 'Origin', 'x-ratelimit-limit-requests': '14400', 'x-ratelimit-limit-tokens': '30000', 'x-ratelimit-remaining-requests': '14398', 'x-ratelimit-remaining-tokens': '29589', 'x-ratelimit-reset-requests': '7.903999999s', 'x-ratelimit-reset-tokens': '822ms', 'x-request-id': 'req_01j5f86190fbdtbqayw9jgkm3p', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=86400', 'cf-cache-status': 'DYNAMIC', 'server': 'cloudflare', 'cf-ray': '8b46c9418895ac2d-YYZ', 'content-encoding': 'br'})
# INFO     entering reviewer node
# INFO     I'm in reviewer router
# {'messages': [HumanMessage(content='I want to drink coffee in Oshawa tomorow'), AIMessage(content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}', response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.169661869, 'queue_time': 0.0017162900000000092, 'total_time': 0.232161869}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-7c86cbe7-cf72-4934-8b1b-4c5be8c1290e-0', usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707}), ToolMessage(content="[{'entity_name': 'Aves Coffee Co.', 'address': '9 William St W, Oshawa, ON L1G 4B7, Canada', 'rate': 4.9, 'estimated_travel_time': '1.43 mins'}, {'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '0.94 mins'}, {'entity_name': 'BOND|ST Cafe', 'address': '44 Bond St E First Floor, Oshawa, ON L1G 1B1, Canada', 'rate': 4.9, 'estimated_travel_time': '0.95 mins'}]", name='GoogleMaps', tool_call_id='call_IoT_engine'), AIMessage(content="I'd be happy to help you find a great spot for coffee in Oshawa! Based on the travel time and rate, I would recommend Aves Coffee Co. or BOND|ST Cafe. Both of these places have excellent reviews and are relatively close to each other. Aves Coffee Co. has a 4.9-star rating and is about a 1.43-minute drive from your location, while BOND|ST Cafe has a 4.9-star rating and is about a 0.95-minute drive away.\n\nPlease note that I couldn't consider estimated service time as I don't have access to real-time sensing data.", response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 433, 'total_tokens': 565, 'completion_time': 0.104302442, 'prompt_time': 0.10151551, 'queue_time': 0.000800149, 'total_time': 0.205817952}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-ed3ad7bf-9b5b-45f8-bada-f881f2f52419-0', usage_metadata={'input_tokens': 433, 'output_tokens': 132, 'total_tokens': 565})], 'handled': [None, True, None, True], 'make_sense': [None, None, None, True], 'node': ['assistant_agent', 'GoogleMaps', 'generator_agent', None], 'query': 'I want to drink coffee in Oshawa tomorrow', 'response': ["I'd be happy to help you find a great spot for coffee in Oshawa! Based on the travel time and rate, I would recommend Aves Coffee Co. or BOND|ST Cafe. Both of these places have excellent reviews and are relatively close to each other. Aves Coffee Co. has a 4.9-star rating and is about a 1.43-minute drive from your location, while BOND|ST Cafe has a 4.9-star rating and is about a 0.95-minute drive away.\n\nPlease note that I couldn't consider estimated service time as I don't have access to real-time sensing data."], 'context': "[{'entity_name': 'Aves Coffee Co.', 'address': '9 William St W, Oshawa, ON L1G 4B7, Canada', 'rate': 4.9, 'estimated_travel_time': '1.43 mins'}, {'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '0.94 mins'}, {'entity_name': 'BOND|ST Cafe', 'address': '44 Bond St E First Floor, Oshawa, ON L1G 1B1, Canada', 'rate': 4.9, 'estimated_travel_time': '0.95 mins'}]", 'call': 'generator_agent', 'location_finder_results': {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}}
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33

# %%
result["respnse"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result["respnse"]
#
# NameError: name 'result' is not defined

# %%
messages = [HumanMessage(content="I want to drink coffee in Oshawa tomorow")]
thread = {"configurable": {"thread_id": "2"}}
for event in runnable.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# DEBUG    Starting new HTTPS connection (1): api.smith.langchain.com:443
# INFO     entering assistant node
# DEBUG    Request options: {'method': 'post', 'url': '/openai/v1/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\nAct as an assistant  and answer user queries ONLY if you can \nUser queries may fall into one of the following categories:\n1- Greeting/General: Greeting you or answering a general question that you can ONLY answer, or thank you at the end of the conversations.\n2- Service Recommendation: Asking for a recommendation for a service or a place to visit, such as I want to drink coffee, I am looking for a Middle Eastern restaurant, or Do you know any close hospital?\n3- Hard Question: General questions you can\'t answer, such as: who is the current president of the United States of America? Or any question related to current events happening as you don\'t have access to the current event happening right now. the user may ask you to look for it\nYour response must follow the following JSON  objects based on each category:\n 1- Greeting/General: you need to provide your response ONLY in a JSON object as shown:\n{\n  "query-type": "greeting-general", // String: Type of the query (e.g., Hello, what\'s the internet?)\n  "response": "write your response here" // String: The response from the LLM\n}\n2-Service Recommendation: try to extract the service type and the city, country, Address, or Coordinates if mentioned. Your response is ONLY a JSON object. This JSON object must follow the following structure and set "" (empty string) for the value of the keys that you can\'t extract.\n{\n  "query-type": "service-recommendation", // String: Type of the query (e.g., coffee shop)\n  "service": "extracted service type", // String: The type of service extracted from the user\'s input\n  "city": "extracted city", // String: The city name extracted from the user\'s input\n  "country": "extracted country", // String: The country name extracted from the user\'s input \n  "address": "extracted address", // String: The full address extracted from the user\'s input\n  "coordinates": [extracted_latitude, extracted_longitude], // Array of Numbers: The latitude and longitude coordinates (e.g., [12.34, 56.78]) and set [0, 0] if not extracted.\n  "question": "extracted question based on the context of the user conversation" // String: The user\'s question or request extracted based on context\n}\n3- Hard Question/current events: extract the question from the user context and provide your response ONLY JSON object as shown:\n{\n  "query-type": "hard-question", // String: Type of the query (e.g., what\'s happening now in Egypt? )\n  "question": "extracted question based on the context of the user conversation" // String: The specific hard question extracted from the user\'s conversation context\n}\n\nRespond ONLY with one of the JSON objects defined above without writing the provided comments on each key-value.\n'}, {'role': 'user', 'content': 'I want to drink coffee in Oshawa tomorow'}], 'model': 'llama3-8b-8192', 'n': 1, 'stop': None, 'stream': False, 'temperature': 1e-08}}
# DEBUG    Sending HTTP Request: POST https://api.groq.com/openai/v1/chat/completions
# DEBUG    connect_tcp.started host='api.groq.com' port=443 local_address=None timeout=None socket_options=None
# DEBUG    connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002959D25FCD0>
# DEBUG    start_tls.started ssl_context=<ssl.SSLContext object at 0x000002958CF52960> server_hostname='api.groq.com' timeout=None
# DEBUG    start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002959D25FE50>
# DEBUG    send_request_headers.started request=<Request [b'POST']>
# DEBUG    send_request_headers.complete
# DEBUG    send_request_body.started request=<Request [b'POST']>
# DEBUG    send_request_body.complete
# DEBUG    receive_response_headers.started request=<Request [b'POST']>
# DEBUG    receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Aug 2024 03:30:13 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Cache-Control', b'private, max-age=0, no-store, no-cache, must-revalidate'), (b'vary', b'Origin'), (b'x-ratelimit-limit-requests', b'14400'), (b'x-ratelimit-limit-tokens', b'30000'), (b'x-ratelimit-remaining-requests', b'14399'), (b'x-ratelimit-remaining-tokens', b'29308'), (b'x-ratelimit-reset-requests', b'6s'), (b'x-ratelimit-reset-tokens', b'1.384s'), (b'x-request-id', b'req_01j5f65de7erst1csrtn2bp11b'), (b'via', b'1.1 google'), (b'alt-svc', b'h3=":443"; ma=86400'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=FcwDanZbs3vsDL7xy0j_7zd1b0oDeYbBZYFHvNf4Rns-1723865413-1.0.1.1-6gwonCuHJI5tFVWDl5OkjMAbtiF8fnT95MODAR2alVkTD9aemPLKI6BLx1bjg_AK1eX766rZoZ8KuL1qS5VtiA; path=/; expires=Sat, 17-Aug-24 04:00:13 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8b46958f6a5636fb-YYZ'), (b'Content-Encoding', b'br')])
# INFO     HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG    receive_response_body.started request=<Request [b'POST']>
# DEBUG    receive_response_body.complete
# DEBUG    response_closed.started
# DEBUG    response_closed.complete
# DEBUG    HTTP Response: POST https://api.groq.com/openai/v1/chat/completions "200 OK" Headers({'date': 'Sat, 17 Aug 2024 03:30:13 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'private, max-age=0, no-store, no-cache, must-revalidate', 'vary': 'Origin', 'x-ratelimit-limit-requests': '14400', 'x-ratelimit-limit-tokens': '30000', 'x-ratelimit-remaining-requests': '14399', 'x-ratelimit-remaining-tokens': '29308', 'x-ratelimit-reset-requests': '6s', 'x-ratelimit-reset-tokens': '1.384s', 'x-request-id': 'req_01j5f65de7erst1csrtn2bp11b', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=86400', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=FcwDanZbs3vsDL7xy0j_7zd1b0oDeYbBZYFHvNf4Rns-1723865413-1.0.1.1-6gwonCuHJI5tFVWDl5OkjMAbtiF8fnT95MODAR2alVkTD9aemPLKI6BLx1bjg_AK1eX766rZoZ8KuL1qS5VtiA; path=/; expires=Sat, 17-Aug-24 04:00:13 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None', 'server': 'cloudflare', 'cf-ray': '8b46958f6a5636fb-YYZ', 'content-encoding': 'br'})
# INFO     content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}' response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.098768172, 'queue_time': 0.0007974869999999995, 'total_time': 0.161268172}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None} id='run-3dea529a-b27f-4bcd-82dc-103ddd8cbee3-0' usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707}
# DEBUG    Nominatim.geocode: https://nominatim.openstreetmap.org/search?q=Oshawa&format=json&limit=1
# DEBUG    Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# DEBUG    https://api.smith.langchain.com:443 "GET /info HTTP/1.1" 200 455
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /search?q=Oshawa&format=json&limit=1 HTTP/1.1" 200 453
# DEBUG    Nominatim.reverse: https://nominatim.openstreetmap.org/reverse?lat=43.8975558&lon=-78.8635324&format=json&addressdetails=1
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /reverse?lat=43.8975558&lon=-78.8635324&format=json&addressdetails=1 HTTP/1.1" 200 787
# DEBUG    Nominatim.geocode: https://nominatim.openstreetmap.org/search?q=Oshawa&format=json&limit=1
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33
# DEBUG    https://nominatim.openstreetmap.org:443 "GET /search?q=Oshawa&format=json&limit=1 HTTP/1.1" 200 453
# INFO     {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}
# INFO     GoogleMaps
# INFO     {'node': ['assistant_agent'], 'location_finder_results': {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}, 'call': 'GoogleMaps', 'query': 'I want to drink coffee in Oshawa tomorrow', 'messages': [AIMessage(content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}', response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.098768172, 'queue_time': 0.0007974869999999995, 'total_time': 0.161268172}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-3dea529a-b27f-4bcd-82dc-103ddd8cbee3-0', usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707})]}
# {'messages': [AIMessage(content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}', response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.098768172, 'queue_time': 0.0007974869999999995, 'total_time': 0.161268172}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-3dea529a-b27f-4bcd-82dc-103ddd8cbee3-0', usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707})], 'handled': [None], 'make_sense': [None], 'node': ['assistant_agent'], 'query': 'I want to drink coffee in Oshawa tomorrow', 'call': 'GoogleMaps', 'location_finder_results': {'city': 'Oshawa', 'country': 'Canada', 'coordinates': (43.8975558, -78.8635324)}}
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33

# %%
State=runnable.get_state(thread)
State
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='I want to drink coffee in Oshawa tomorow'), AIMessage(content='{\n  "query-type": "service-recommendation",\n  "service": "coffee shop",\n  "city": "Oshawa",\n  "country": "Canada",\n  "address": "",\n  "coordinates": [43.9003, -78.8793],\n  "question": "I want to drink coffee in Oshawa tomorrow"\n}', response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 632, 'total_tokens': 707, 'completion_time': 0.0625, 'prompt_time': 0.169661869, 'queue_time': 0.0017162900000000092, 'total_time': 0.232161869}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-7c86cbe7-cf72-4934-8b1b-4c5be8c1290e-0', usage_metadata={'input_tokens': 632, 'output_tokens': 75, 'total_tokens': 707}), ToolMessage(content="[{'entity_name': 'Aves Coffee Co.', 'address': '9 William St W, Oshawa, ON L1G 4B7, Canada', 'rate': 4.9, 'estimated_travel_time': '1.43 mins'}, {'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '0.94 mins'}, {'entity_name': 'BOND|ST Cafe', 'address': '44 Bond St E First Floor, Oshawa, ON L1G 1B1, Canada', 'rate': 4.9, 'estimated_travel_time': '0.95 mins'}]", name='GoogleMaps', tool_call_id='call_IoT_engine'), AIMessage(content="I'd be happy to help you find a great spot for coffee in Oshawa! Based on the travel time and rate, I would recommend Aves Coffee Co. or BOND|ST Cafe. Both of these places have excellent reviews and are relatively close to each other. Aves Coffee Co. has a 4.9-star rating and is about a 1.43-minute drive from your location, while BOND|ST Cafe has a 4.9-star rating and is about a 0.95-minute drive away.\n\nPlease note that I couldn't consider estimated service time as I don't have access to real-time sensing data.", response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 433, 'total_tokens': 565, 'completion_time': 0.104302442, 'prompt_time': 0.10151551, 'queue_time': 0.000800149, 'total_time': 0.205817952}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-ed3ad7bf-9b5b-45f8-bada-f881f2f52419-0', usage_metadata={'input_tokens': 433, 'output_tokens': 132, 'total_tokens': 565})], 'handled': [None, True, None, True], 'make_sense': [None, None, None, True], 'node': ['assistant_agent', 'GoogleMaps', 'generator_agent', None], 'query': 'I want to drink coffee in Oshawa tomorrow', 'response': ["I'd be happy to help you find a great spot for coffee in Oshawa! Based on the travel time and rate, I would recommend Aves Coffee Co. or BOND|ST Cafe. Both of these places have excellent reviews and are relatively close to each other. Aves Coffee Co. has a 4.9-star rating and is about a 1.43-minute drive from your location, while BOND|ST Cafe has a 4.9-star rating and is about a 0.95-minute drive away.\n\nPlease note that I couldn't consider estimated service time as I don't have access to real-time sensing data."], 'context': "[{'entity_name': 'Aves Coffee Co.', 'address': '9 William St W, Oshawa, ON L1G 4B7, Canada', 'rate': 4.9, 'estimated_travel_time': '1.43 mins'}, {'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '0.94 mins'}, {'entity_name': 'BOND|ST Cafe', 'address': '44 Bond St E First Floor, Oshawa, ON L1G 1B1, Canada', 'rate': 4.9, 'estimated_travel_time': '0.95 mins'}]", 'call': 'generator_agent', 'location_finder_results': {'city': 'Oshawa', 'country': 'Canada', 'coordinates': [43.8975558, -78.8635324]}}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef5c4df-04f0-659b-8004-820edaad67c5'}}, metadata={'source': 'loop', 'writes': {'reviewer_agent': {'handled': [True], 'make_sense': [True], 'node': [None]}}, 'step': 4}, created_at='2024-08-17T04:05:28.572252+00:00', parent_config={'configurabl ...

# %%
print(State.values["messages"][-1].content)
print(State.values["call"])
print(State.values["location_finder_results"])
# Out:
# I'd be happy to help you find a great spot for coffee in Oshawa! Based on the travel time and rate, I would recommend Aves Coffee Co. or BOND|ST Cafe. Both of these places have excellent reviews and are relatively close to each other. Aves Coffee Co. has a 4.9-star rating and is about a 1.43-minute drive from your location, while BOND|ST Cafe has a 4.9-star rating and is about a 0.95-minute drive away.
#
# Please note that I couldn't consider estimated service time as I don't have access to real-time sensing data.
# generator_agent
# {'city': 'Oshawa', 'country': 'Canada', 'coordinates': [43.8975558, -78.8635324]}

# %%
thread = {"configurable": {"thread_id": "25f"}}


human_message = HumanMessage(content="do you know anything about langgraph?")
messages = [human_message]

# for event in runnable.stream(prepaer_states({"messages":messages}), thread):
#     for v in event.values():
#         print(v['messages'])
        
for event in runnable.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while runnable.get_state(thread).next:
    print("\n", runnable.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in runnable.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# INFO     entering assistant node
# DEBUG    Starting new HTTPS connection (1): api.smith.langchain.com:443
# DEBUG    Request options: {'method': 'post', 'url': '/openai/v1/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\nAct as an assistant  and answer user queries ONLY if you can \nUser queries may fall into one of the following categories:\n1- Greeting/General: Greeting you or answering a general question that you can ONLY answer.\n2- Service Recommendation: Asking for a recommendation for a service or a place to visit, such as I want to drink coffee, I am looking for a Middle Eastern restaurant, or Do you know any close hospital?\n3- Hard Question: General questions you can\'t answer, such as: who is the current president of the United States of America? Or any question related to current events happening as you don\'t have access to the current event happening right now. the user may ask you to look for it\nYour response must follow the following JSON  objects based on each category:\n 1- Greeting/General: you need to provide your response ONLY in a JSON object as shown:\n{\n  "query-type": "greeting-general", // String: Type of the query (e.g., Hello, what\'s the internet?)\n  "response": "write your response here" // String: The response from the LLM\n}\n2-Service Recommendation: try to extract the service type and the city, country, Address, or Coordinates if mentioned. Your response is ONLY a JSON object. This JSON object must follow the following structure and set false in bool format for the value of the keys that you can\'t extract.\n{\n  "query-type": "service-recommendation", // String: Type of the query (e.g., coffee shop)\n  "service": "extracted service type", // String: The type of service extracted from the user\'s input\n  "city": "extracted city", // String: The city name extracted from the user\'s input\n  "country": "extracted country", // String: The country name extracted from the user\'s input \n  "address": "extracted address", // String: The full address extracted from the user\'s input\n  "coordinates": [extracted_latitude, extracted_longitude], // Array of Numbers: The latitude and longitude coordinates (e.g., [12.34, 56.78])\n  "question": "extracted question based on the context of the user conversation" // String: The user\'s question or request extracted based on context\n}\n3- Hard Question/current events: extract the question from the user context and provide your response ONLY JSON object as shown:\n{\n  "query-type": "hard-question", // String: Type of the query (e.g., what\'s happening now in Egypt? )\n  "question": "extracted question based on the context of the user conversation" // String: The specific hard question extracted from the user\'s conversation context\n}\n\n'}, {'role': 'user', 'content': 'do you know anything about langgraph?'}], 'model': 'llama3-8b-8192', 'n': 1, 'stop': None, 'stream': False, 'temperature': 1e-08}}
# DEBUG    Sending HTTP Request: POST https://api.groq.com/openai/v1/chat/completions
# DEBUG    connect_tcp.started host='api.groq.com' port=443 local_address=None timeout=None socket_options=None
# DEBUG    connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000018D948FF750>
# DEBUG    start_tls.started ssl_context=<ssl.SSLContext object at 0x0000018D82DB2BA0> server_hostname='api.groq.com' timeout=None
# DEBUG    start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000018D94A34090>
# DEBUG    send_request_headers.started request=<Request [b'POST']>
# DEBUG    send_request_headers.complete
# DEBUG    send_request_body.started request=<Request [b'POST']>
# DEBUG    send_request_body.complete
# DEBUG    receive_response_headers.started request=<Request [b'POST']>
# DEBUG    receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 16 Aug 2024 15:41:58 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Cache-Control', b'private, max-age=0, no-store, no-cache, must-revalidate'), (b'vary', b'Origin'), (b'x-ratelimit-limit-requests', b'14400'), (b'x-ratelimit-limit-tokens', b'30000'), (b'x-ratelimit-remaining-requests', b'14399'), (b'x-ratelimit-remaining-tokens', b'29356'), (b'x-ratelimit-reset-requests', b'6s'), (b'x-ratelimit-reset-tokens', b'1.288s'), (b'x-request-id', b'req_01j5dxmj9mfjfvrvn9qrk3y370'), (b'via', b'1.1 google'), (b'alt-svc', b'h3=":443"; ma=86400'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=8Y06ZDmWzo_IUMaKljF5zZyJe31xD26llklYLlYoKQE-1723822918-1.0.1.1-Az_QUAN8OxQlHSRFqXau1AOSaSpBUqucHRHqxpDoili_Weox8BhBfedHLDzqd2Qr2wFd8VhAqJDTim1y7pfSfw; path=/; expires=Fri, 16-Aug-24 16:11:58 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8b428812e83baacd-YYZ'), (b'Content-Encoding', b'br')])
# INFO     HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG    receive_response_body.started request=<Request [b'POST']>
# DEBUG    receive_response_body.complete
# DEBUG    response_closed.started
# DEBUG    response_closed.complete
# DEBUG    HTTP Response: POST https://api.groq.com/openai/v1/chat/completions "200 OK" Headers({'date': 'Fri, 16 Aug 2024 15:41:58 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'private, max-age=0, no-store, no-cache, must-revalidate', 'vary': 'Origin', 'x-ratelimit-limit-requests': '14400', 'x-ratelimit-limit-tokens': '30000', 'x-ratelimit-remaining-requests': '14399', 'x-ratelimit-remaining-tokens': '29356', 'x-ratelimit-reset-requests': '6s', 'x-ratelimit-reset-tokens': '1.288s', 'x-request-id': 'req_01j5dxmj9mfjfvrvn9qrk3y370', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=86400', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=8Y06ZDmWzo_IUMaKljF5zZyJe31xD26llklYLlYoKQE-1723822918-1.0.1.1-Az_QUAN8OxQlHSRFqXau1AOSaSpBUqucHRHqxpDoili_Weox8BhBfedHLDzqd2Qr2wFd8VhAqJDTim1y7pfSfw; path=/; expires=Fri, 16-Aug-24 16:11:58 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None', 'server': 'cloudflare', 'cf-ray': '8b428812e83baacd-YYZ', 'content-encoding': 'br'})
# INFO     content='{\n  "query-type": "greeting-general", \n  "response": "LangGraph is a fascinating topic! LangGraph is a graph-based language model that aims to capture the complex relationships between words, phrases, and concepts in natural language. It\'s a relatively new area of research in the field of natural language processing. Would you like to know more about it?"\n}' response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 585, 'total_tokens': 662, 'completion_time': 0.060646568, 'prompt_time': 0.124778114, 'queue_time': 0.011636475000000007, 'total_time': 0.185424682}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None} id='run-5e7c8244-8730-42e2-b39d-e13e6d9120f5-0' usage_metadata={'input_tokens': 585, 'output_tokens': 77, 'total_tokens': 662}
# INFO     {'node': ['assistant_agent'], 'call': 'reviewer_agent', 'response': "LangGraph is a fascinating topic! LangGraph is a graph-based language model that aims to capture the complex relationships between words, phrases, and concepts in natural language. It's a relatively new area of research in the field of natural language processing. Would you like to know more about it?", 'messages': [AIMessage(content='{\n  "query-type": "greeting-general", \n  "response": "LangGraph is a fascinating topic! LangGraph is a graph-based language model that aims to capture the complex relationships between words, phrases, and concepts in natural language. It\'s a relatively new area of research in the field of natural language processing. Would you like to know more about it?"\n}', response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 585, 'total_tokens': 662, 'completion_time': 0.060646568, 'prompt_time': 0.124778114, 'queue_time': 0.011636475000000007, 'total_time': 0.185424682}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-5e7c8244-8730-42e2-b39d-e13e6d9120f5-0', usage_metadata={'input_tokens': 585, 'output_tokens': 77, 'total_tokens': 662})]}
# INFO     entering reviewer node
# INFO     I'm in reviewer router
# {'messages': [AIMessage(content='{\n  "query-type": "greeting-general", \n  "response": "LangGraph is a fascinating topic! LangGraph is a graph-based language model that aims to capture the complex relationships between words, phrases, and concepts in natural language. It\'s a relatively new area of research in the field of natural language processing. Would you like to know more about it?"\n}', response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 585, 'total_tokens': 662, 'completion_time': 0.060646568, 'prompt_time': 0.124778114, 'queue_time': 0.011636475000000007, 'total_time': 0.185424682}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-5e7c8244-8730-42e2-b39d-e13e6d9120f5-0', usage_metadata={'input_tokens': 585, 'output_tokens': 77, 'total_tokens': 662})], 'handled': [None], 'make_sense': [None], 'node': ['assistant_agent'], 'response': "LangGraph is a fascinating topic! LangGraph is a graph-based language model that aims to capture the complex relationships between words, phrases, and concepts in natural language. It's a relatively new area of research in the field of natural language processing. Would you like to know more about it?", 'call': 'reviewer_agent'}
# {'handled': [True], 'make_sense': [True], 'node': [None]}
# DEBUG    https://api.smith.langchain.com:443 "GET /info HTTP/1.1" 200 455
# DEBUG    https://api.smith.langchain.com:443 "POST /runs/batch HTTP/1.1" 202 33

# %%
for i in result:
    print(i)
    print(result[i])
# Out:
# messages
# [HumanMessage(content='Who invented the car'), AIMessage(content='{\n  "query-type": "hard-question",\n  "question": "Who invented the car"\n}', response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 389, 'total_tokens': 411, 'completion_time': 0.016610526, 'prompt_time': 0.077772415, 'queue_time': 0.0008423679999999961, 'total_time': 0.094382941}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-d6257478-000b-4ecd-9349-e4065ea48b26-0', usage_metadata={'input_tokens': 389, 'output_tokens': 22, 'total_tokens': 411}), ToolMessage(content='{\'title\': \'A History of Cars: The Invention of the Automobile - ThoughtCo\', \'url\': \'https://www.thoughtco.com/who-invented-the-car-4059932\', \'content\': "A History of the Automobile\\nThe Evolution of the Car Dates All the Way Back to the 1600s\\nThe very first self-powered road vehicles were powered by steam engines, and by that definition, Nicolas Joseph Cugnot of France built the\\xa0first automobile\\xa0in 1769 — recognized by the British Royal Automobile Club and the Automobile Club de France as being the first. If Siegfried Marcus built his second car in 1875 and it was as claimed, it would have been the first vehicle powered by a four-cycle engine and the first to use gasoline as a fuel, the first having a carburetor for a gasoline engine and the first having a magneto ignition. The Heart of the Automobile\\nAn internal combustion engine is an engine that uses the explosive combustion of fuel to push a piston within a cylinder —\\xa0the piston\'s movement turns a crankshaft that then turns the car wheels via a chain or a drive shaft.\\xa0 A brief outline of the history of the internal combustion engine includes the following highlights:\\nEngine design and car design were integral activities, almost all of the engine designers mentioned above also designed cars, and a few went on to become major manufacturers of automobiles.\\xa0 By car manufacturer we mean builders of entire motor vehicles for sale and not just engine inventors who experimented with car design to test their engines —\\xa0Daimler\\xa0and\\xa0Benz\\xa0began as the latter before becoming full car manufacturers and made their early money by licensing their patents and selling their engines to car manufacturers.\\n", \'score\': 0.99706507, \'raw_content\': None}', name='scrapper', tool_call_id='call_scrapper'), AIMessage(content='Nicolas Joseph Cugnot of France is often credited with building the first automobile in 1769, powered by a steam engine.', response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 447, 'total_tokens': 475, 'completion_time': 0.021406246, 'prompt_time': 0.095883126, 'queue_time': 0.0009513929999999948, 'total_time': 0.117289372}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8325bf2a-f01b-4259-b72a-e7c87f4cd7e5-0', usage_metadata={'input_tokens': 447, 'output_tokens': 28, 'total_tokens': 475}), HumanMessage(content="what's about the bike"), AIMessage(content='{\n "query-type": "hard-question",\n "question": "Who invented the bike?"\n}', response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 404, 'total_tokens': 424, 'completion_time': 0.015484873, 'prompt_time': 0.061729853, 'queue_time': 0.0012963770000000013, 'total_time': 0.077214726}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-bcaa8b77-4aad-4484-9708-1dd73e5658ff-0', usage_metadata={'input_tokens': 404, 'output_tokens': 20, 'total_tokens': 424}), ToolMessage(content='{\'title\': "The Bicycle\'s Bumpy History", \'url\': \'https://www.history.com/news/bicycle-history-invention\', \'content\': \'Who invented the bicycle? The answer is a little more complicated than you may think. A German baron named Karl von Drais made the first major development whe ...
# handled
# [None, True, None, True, None, True, None, True]
# make_sense
# [None, None, None, True, None, None, None, True]
# node
# ['assistant_agent', 'scrapper', 'generator_agent', None, 'assistant_agent', 'scrapper', 'generator_agent', None]
# query
# Who invented the bike?
# response
# According to the context, the first major development of the bicycle was made by a German baron named Karl von Drais, who created a steerable, two-wheeled vehicle. However, it's not clear if he is the inventor of the bike as a whole.
# context
# {'title': "The Bicycle's Bumpy History", 'url': 'https://www.history.com/news/bicycle-history-invention', 'content': 'Who invented the bicycle? The answer is a little more complicated than you may think. A German baron named Karl von Drais made the first major development when he created a steerable, two-wheeled ...', 'score': 0.9949397, 'raw_content': None}
# call
# scrapper

# %%
print(result["response"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(result["response"])
#
# KeyError: 'response'

# %%
import requests

class GoogleMapsTextSearchClient:
    def __init__(self, api_key):
        self.api_key = api_key
        self.text_search_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
        self.distance_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

    def text_search(self, query):
        params = {
            'query': query,
            'key': self.api_key,
            "minprice":0
        }
        response = requests.get(self.text_search_url, params=params)
        if response.status_code == 200:
            return response.json().get('results', [])
        else:
            response.raise_for_status()

    def get_travel_time(self, origin_latitude, origin_longitude, destination_latitude, destination_longitude):
        params = {
            'origins': f'{origin_latitude},{origin_longitude}',
            'destinations': f'{destination_latitude},{destination_longitude}',
            'key': self.api_key
        }
        response = requests.get(self.distance_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            # Log the full response for debugging
            print("Distance Matrix API Response:", data)
            # Check if 'rows' and 'elements' exist in the response
            if 'rows' in data and len(data['rows']) > 0:
                if 'elements' in data['rows'][0] and len(data['rows'][0]['elements']) > 0:
                    element = data['rows'][0]['elements'][0]
                    if 'duration' in element:
                        return element['duration'].get('text', 'N/A')
                    else:
                        return 'Duration data not available'
                else:
                    return 'Elements data not available'
            else:
                return 'Rows data not available'
        else:
            response.raise_for_status()

        return 'N/A'

    def text_search_with_details(self, query, origin_latitude, origin_longitude):
        places = self.text_search(query)
        places_with_details = []
        for place in places:
            name = place.get('name', 'N/A')
            address = place.get('formatted_address', 'N/A')
            rating = place.get('rating', 'N/A')
            destination_latitude = place['geometry']['location']['lat']
            destination_longitude = place['geometry']['location']['lng']
            travel_time = self.get_travel_time(origin_latitude, origin_longitude, destination_latitude, destination_longitude)
            places_with_details.append({
                'entity_name': name,
                'address': address,
                'rate': rating,
                'estimated_travel_time': travel_time
            })
        return places_with_details

# Example usage:
import os
# Constants for JWT token
GKGraph_API_KEY = os.environ.get("GKGraph_API_KEY") 
gmaps_text_search_client = GoogleMapsTextSearchClient(GKGraph_API_KEY)
results = gmaps_text_search_client.text_search_with_details("I want to drink coffee in a place close to me", 37.7749, -122.4194)
print(results)
# Out:
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/place/textsearch/json?query=I+want+to+drink+coffee+in+a+place+close+to+me&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk&minprice=0 HTTP/1.1" 200 42963
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8978262%2C-78.86398609999999&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 626
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['8 Simcoe St N, Oshawa, ON L1G 4R8, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,288 km', 'value': 4288313}, 'duration': {'text': '1 day 15 hours', 'value': 138869}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.9364206%2C-78.85532890000002&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 631
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['1280 Clearbrook Dr, Oshawa, ON L1H 7K5, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,299 km', 'value': 4298565}, 'duration': {'text': '1 day 15 hours', 'value': 138843}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8958249%2C-78.8618013&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 625
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['72 Celina St, Oshawa, ON L1H 4N2, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,288 km', 'value': 4288354}, 'duration': {'text': '1 day 15 hours', 'value': 138882}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8919982%2C-78.88099009999999&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 626
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['501 King St W, Oshawa, ON L1J 2K9, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4286640}, 'duration': {'text': '1 day 15 hours', 'value': 138763}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8971589%2C-78.8659934&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 625
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['62 King St W, Oshawa, ON L1H 1A6, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,288 km', 'value': 4287951}, 'duration': {'text': '1 day 15 hours', 'value': 138871}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8919982%2C-78.88099009999999&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 626
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['501 King St W, Oshawa, ON L1J 2K9, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4286640}, 'duration': {'text': '1 day 15 hours', 'value': 138763}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.897574%2C-78.8646771&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 625
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['22 King St W, Oshawa, ON L1H 1A1, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,288 km', 'value': 4288074}, 'duration': {'text': '1 day 15 hours', 'value': 138932}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.9114837%2C-78.89055689999999&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 630
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['500 Rossland Rd W, Oshawa, ON L1J 3H2, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,294 km', 'value': 4294141}, 'duration': {'text': '1 day 15 hours', 'value': 138795}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.9059569%2C-78.8109616&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 636
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['1413 King St E Unit 6, Courtice, ON L1E 2J6, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,292 km', 'value': 4292369}, 'duration': {'text': '1 day 15 hours', 'value': 139032}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8672741%2C-78.932949&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 629
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['185 Consumers Dr, Whitby, ON L1N 1C4, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,281 km', 'value': 4280890}, 'duration': {'text': '1 day 14 hours', 'value': 138454}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.9191043%2C-78.8510319&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 630
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['555 Rossland Rd E, Oshawa, ON L1K 1K8, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,301 km', 'value': 4300854}, 'duration': {'text': '1 day 15 hours', 'value': 139041}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8808565%2C-78.9428119&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 627
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['132 Brock St N, Whitby, ON L1N 4H4, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,282 km', 'value': 4281970}, 'duration': {'text': '1 day 14 hours', 'value': 138578}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.894117%2C-78.8780626&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 626
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['399 King St W, Oshawa, ON L1J 2K4, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4287144}, 'duration': {'text': '1 day 15 hours', 'value': 138781}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.963691%2C-78.9035827&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 629
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['2630 Simcoe St N, Oshawa, ON L1H 7K4, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,290 km', 'value': 4290476}, 'duration': {'text': '1 day 14 hours', 'value': 138399}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8865021%2C-78.8579084&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 636
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['433 Simcoe St S Unit #3, Oshawa, ON L1H 4J5, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4287002}, 'duration': {'text': '1 day 15 hours', 'value': 138668}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8958705%2C-78.8720838&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 625
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['1 Warren Ave, Oshawa, ON L1J 4E2, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4287479}, 'duration': {'text': '1 day 15 hours', 'value': 138829}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.933682%2C-78.87766560000001&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 635
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['50 Taunton Rd E Unit 1, Oshawa, ON L1G 3T7, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,294 km', 'value': 4293745}, 'duration': {'text': '1 day 15 hours', 'value': 138724}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8857047%2C-78.9154271&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 629
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['1525 Dundas St E, Whitby, ON L1N 2K6, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,284 km', 'value': 4284496}, 'duration': {'text': '1 day 15 hours', 'value': 138687}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.89949499999999%2C-78.8642696&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 627
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# Distance Matrix API Response: {'destination_addresses': ['67 Simcoe St N, Oshawa, ON L1G 4S3, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,288 km', 'value': 4288497}, 'duration': {'text': '1 day 15 hours', 'value': 138901}, 'status': 'OK'}]}], 'status': 'OK'}
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/distancematrix/json?origins=37.7749%2C-122.4194&destinations=43.8952335%2C-78.8731797&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 626
# Distance Matrix API Response: {'destination_addresses': ['245 King St W, Oshawa, ON L1J 2J7, Canada'], 'origin_addresses': ['5911 US-101, San Francisco, CA 94103, USA'], 'rows': [{'elements': [{'distance': {'text': '4,287 km', 'value': 4287337}, 'duration': {'text': '1 day 15 hours', 'value': 138780}, 'status': 'OK'}]}], 'status': 'OK'}
# [{'entity_name': 'Cork & Bean', 'address': '8 Simcoe St N, Oshawa, ON L1G 4R8, Canada', 'rate': 4.6, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'D Spot Dessert Cafe Oshawa', 'address': '1280 Clearbrook Dr Unit 2A, Oshawa, ON L1K 3G6, Canada', 'rate': 4.9, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Brew Wizards Board Game Café', 'address': '74 Celina St, Oshawa, ON L1H 4N2, Canada', 'rate': 4.7, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Good Earth Coffeehouse - Oshawa', 'address': '419 King St W, Oshawa, ON L1J 2H9, Canada', 'rate': 4.1, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Oshawa House Cafe', 'address': '62 King St W, Oshawa, ON L1H 1A6, Canada', 'rate': 4.4, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Good Earth Coffeehouse', 'address': '419 King St W, Oshawa, ON L1J 2H9, Canada', 'rate': 4.4, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Coffee Culture Cafe & Eatery', 'address': '22 King St W, Oshawa, ON L1H 1A1, Canada', 'rate': 3.9, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Coffee Time', 'address': '500 Rossland Rd W, Oshawa, ON L1J 3H2, Canada', 'rate': 4.1, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Deadly Grounds Café and Curiosities', 'address': '1413 King St E Unit 6, Courtice, ON L1E 2J6, Canada', 'rate': 4.8, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Mr. Puffs', 'address': '185 Consumers Dr, Whitby, ON L1N 1C4, Canada', 'rate': 4.6, 'estimated_travel_time': '1 day 14 hours'}, {'entity_name': 'Coffee Culture Café & Eatery', 'address': '555 Rossland Rd E, Oshawa, ON L1K 1K8, Canada', 'rate': 4.3, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Jacked Up Coffee Roasting Co.', 'address': '132 Brock St N, Whitby, ON L1N 4H4, Canada', 'rate': 4.7, 'estimated_travel_time': '1 day 14 hours'}, {'entity_name': 'CoCo Fresh Tea & Juice', 'address': '399 King St W, Oshawa, ON L1J 2K4, Canada', 'rate': 4.7, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Symposium Cafe Restaurant | OSHAWA', 'address': '2630 Simcoe St N, Oshawa, ON L1H 7K4, Canada', 'rate': 4.3, 'estimated_travel_time': '1 day 14 hours'}, {'entity_name': 'South-End Diner', 'address': '433 Simcoe St S Unit #3, Oshawa, ON L1H 4J5, Canada', 'rate': 4.6, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Coco Frutti Oshawa', 'address': '1 Warren Ave, Oshawa, ON L1J 4E2, Canada', 'rate': 4.4, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': "Hardy John's Bar & Grill Oshawa", 'address': '50 Taunton Rd E Unit 1, Oshawa, ON L1G 3T7, Canada', 'rate': 4.6, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': 'Coffee Culture Cafe & Eatery', 'address': '1525 Dundas St E, Whitby, ON L1N 2K6, Canada', 'rate': 4.1, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': "Wendel Clark's Classic Grill & Bar", 'address': '67 Simcoe St N, Oshawa, ON L1G 4S3, Canada', 'rate': 4, 'estimated_travel_time': '1 day 15 hours'}, {'entity_name': "Teddy's Restaurant & Deli", 'address': '245 King St W, Oshawa, ON L1J 2J7, Canada', 'rate': 4.5, 'estimated_travel_time': '1 day 15 hours'}]

# %%
for i in results:
    print(i)
# Out:
# {'entity_name': 'The Coffee Movement', 'address': '1737 Balboa St, San Francisco, CA 94121, United States', 'rate': 4.8, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'CoffeeShop', 'address': '3139 Mission St, San Francisco, CA 94110, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Delah Coffee', 'address': '370 4th St, San Francisco, CA 94107, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Scullery', 'address': '687 Geary St, San Francisco, CA 94102, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Sextant Coffee Roasters', 'address': '1415 Folsom St, San Francisco, CA 94103, United States', 'rate': 4.4, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Abanico Coffee Roasters', 'address': '2121 Mission St, San Francisco, CA 94110, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Flywheel Coffee Roasters', 'address': '672 Stanyan St, San Francisco, CA 94117, United States', 'rate': 4.5, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Sightglass Coffee', 'address': '270 7th St, San Francisco, CA 94103, United States', 'rate': 4.5, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'The Coffee Movement', 'address': '1030 Washington St, San Francisco, CA 94108, United States', 'rate': 4.8, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'CoffeeShop', 'address': '2761 21st St, San Francisco, CA 94110, United States', 'rate': 4.8, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Grand Coffee', 'address': '2663 Mission St, San Francisco, CA 94110, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Home Coffee Roasters', 'address': '455 Grant Ave, San Francisco, CA 94108, United States', 'rate': 4.7, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Wrecking Ball Coffee Roasters', 'address': '2271 Union St, San Francisco, CA 94123, United States', 'rate': 4.4, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Hey Neighbor Cafe', 'address': '2 Burrows St, San Francisco, CA 94134, United States', 'rate': 4.8, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'The Coffee Berry SF', 'address': '1410 Lombard St, San Francisco, CA 94123, United States', 'rate': 5, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': "Farley's Coffeehouse", 'address': '1315 18th St, San Francisco, CA 94107, United States', 'rate': 4.6, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Caffe Trieste', 'address': '601 Vallejo St., San Francisco, CA 94133, United States', 'rate': 4.5, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'The Interval at Long Now', 'address': 'Center Building A, 2 Marina Blvd, San Francisco, CA 94123, United States', 'rate': 4.8, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Andytown Coffee Roasters', 'address': '3655 Lawton St, San Francisco, CA 94122, United States', 'rate': 4.6, 'estimated_travel_time': 'Rows data not available'}
# {'entity_name': 'Home Coffee Roasters', 'address': '1222 Noriega St, San Francisco, CA 94122, United States', 'rate': 4.6, 'estimated_travel_time': 'Rows data not available'}

# %%
import requests

class GoogleMapsTextSearchClient:
    def __init__(self, google_api_key=None, osm_api_key=None):
        self.google_api_key = google_api_key
        self.osm_api_key = osm_api_key  # OSRM does not require an API key, but added for extensibility
        self.text_search_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
        self.osrm_url = "http://router.project-osrm.org/table/v1/driving/"
    
    def text_search(self, query, limit=3):
        params = {
            'query': query,
            'key': self.google_api_key
        }
        response = requests.get(self.text_search_url, params=params)
        if response.status_code == 200:
            results = response.json().get('results', [])
            # Limit the number of results to the specified limit
            return results[:limit]
        else:
            response.raise_for_status()

    def get_travel_times(self, origin_latitude, origin_longitude, destinations):
        """
        Calculate travel times from the origin to multiple destinations using OSRM.
        
        :param origin_latitude: Latitude of the origin.
        :param origin_longitude: Longitude of the origin.
        :param destinations: List of (latitude, longitude) tuples for the destinations.
        :return: List of travel times in minutes.
        """
        coords = f"{origin_longitude},{origin_latitude};" + ";".join(
            f"{lon},{lat}" for lat, lon in destinations
        )
        url = f"{self.osrm_url}{coords}"
        params = {
            'annotations': 'duration'
        }
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            durations = data.get('durations', [[]])[0][1:]  # Skip the first value as it is the origin to origin
            travel_times = [duration / 60 for duration in durations]  # Convert seconds to minutes
            return travel_times
        else:
            response.raise_for_status()

        return ['N/A'] * len(destinations)

    def text_search_with_details(self, query, origin_latitude, origin_longitude, limit=3):
        places = self.text_search(query, limit)
        destinations = [
            (place['geometry']['location']['lat'], place['geometry']['location']['lng'])
            for place in places
        ]
        
        # Get travel times for all destinations in one call
        travel_times = self.get_travel_times(origin_latitude, origin_longitude, destinations)
        
        places_with_details = []
        for place, travel_time in zip(places, travel_times):
            name = place.get('name', 'N/A')
            address = place.get('formatted_address', 'N/A')
            rating = place.get('rating', 'N/A')
            places_with_details.append({
                'entity_name': name,
                'address': address,
                'rate': rating,
                'estimated_travel_time': f"{travel_time:.2f} mins" if travel_time != 'N/A' else 'N/A'
            })
        
        return places_with_details

import os
# Constants for JWT token
GKGraph_API_KEY = os.environ.get("GKGraph_API_KEY") 
osm_api_key = os.environ.get("ORS_API_KEY")  # Not needed for OSRM, but could be used for other OSM services
gmaps_text_search_client = GoogleMapsTextSearchClient(GKGraph_API_KEY, osm_api_key)
results = gmaps_text_search_client.text_search_with_details("best coffee shops in San Francisco", 37.7749, -122.4194, limit=3)
print(results)
# Out:
# DEBUG    Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG    https://maps.googleapis.com:443 "GET /maps/api/place/textsearch/json?query=best+coffee+shops+in+San+Francisco&key=AIzaSyCP5G248TLXY3OKi0VC3p_-bLKdqpCMqJk HTTP/1.1" 200 43041
# DEBUG    Starting new HTTP connection (1): router.project-osrm.org:80
# DEBUG    http://router.project-osrm.org:80 "GET /table/v1/driving/-122.4194,37.7749;-122.4778045,37.7764955;-122.4187999,37.7470539;-122.4002244,37.7810165?annotations=duration HTTP/1.1" 200 580
# [{'entity_name': 'The Coffee Movement', 'address': '1737 Balboa St, San Francisco, CA 94121, United States', 'rate': 4.8, 'estimated_travel_time': '11.28 mins'}, {'entity_name': 'CoffeeShop', 'address': '3139 Mission St, San Francisco, CA 94110, United States', 'rate': 4.7, 'estimated_travel_time': '6.94 mins'}, {'entity_name': 'Delah Coffee', 'address': '370 4th St, San Francisco, CA 94107, United States', 'rate': 4.7, 'estimated_travel_time': '3.65 mins'}]

# %%
for i in results:
    print(i)
# Out:
# {'entity_name': 'The Coffee Movement', 'address': '1737 Balboa St, San Francisco, CA 94121, United States', 'rate': 4.8, 'estimated_travel_time': '11.28 mins'}
# {'entity_name': 'CoffeeShop', 'address': '3139 Mission St, San Francisco, CA 94110, United States', 'rate': 4.7, 'estimated_travel_time': '6.94 mins'}
# {'entity_name': 'Delah Coffee', 'address': '370 4th St, San Francisco, CA 94107, United States', 'rate': 4.7, 'estimated_travel_time': '3.65 mins'}
